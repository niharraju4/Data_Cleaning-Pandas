# %% [markdown]
# 1. DEFINE A PANDAS DATAFRAME

# %%
#Series in pandas is one dimensional whereas the pandas dataframe is multifunctional
import pandas as pd

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary
bank_client_df = pd.DataFrame({'Bank Client ID':[111, 222, 333, 444],
                               'Bank Client Name': ['Nihar','Nikhil','Nirup','Gaurav'],
                               'Net Worth[$]':[35000, 3000, 100000, 2000],
                               'Years with BANK':[4,7,8,15]})
bank_client_df
# Out:
#    Bank Client ID Bank Client Name  Net Worth[$]  Years with BANK
# 0             111            Nihar         35000                4
# 1             222           Nikhil          3000                7
# 2             333            Nirup        100000                8
# 3             444           Gaurav          2000               15

# %%
# Let's obtain the data type 
type(bank_client_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# you can only view the first couple of rows using .head()
bank_client_df.head()
# Out:
#    Bank Client ID Bank Client Name  Net Worth[$]  Years with BANK
# 0             111            Nihar         35000                4
# 1             222           Nikhil          3000                7
# 2             333            Nirup        100000                8
# 3             444           Gaurav          2000               15

# %%
# you can only view the last couple of rows using .tail()
bank_client_df.tail()
# Out:
#    Bank Client ID Bank Client Name  Net Worth[$]  Years with BANK
# 0             111            Nihar         35000                4
# 1             222           Nikhil          3000                7
# 2             333            Nirup        100000                8
# 3             444           Gaurav          2000               15

# %%
# You can obtain the shape of the DataFrame (#rows, #columns)
bank_client_df.shape
# Out:
# (4, 4)

# %%
# Obtain DataFrame information 
bank_client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank Client ID    4 non-null      int64
#  1   Bank Client Name  4 non-null      object
#  2   Net Worth[$]      4 non-null      int64
#  3   Years with BANK   4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **A porfolio contains a collection of securities such as stocks, bonds and ETFs. Define a dataframe named 'portfolio_df' that holds 3 different stock ticker symbols, number of shares, and price per share (feel free to choose any stocks)**
# - **Calculate the total value of the porfolio including all stocks**

# %%
portfolio_df = pd.DataFrame({'Stocks':['apple','amazon','google','tesla'],
                             'Ticker':['app','amz','ggl','tsl'],
                             'Number of shares':[30,50,70,100],
                             'Share price':[202,175,160,240],})
portfolio_df
# Out:
#    Stocks Ticker  Number of shares  Share price
# 0   apple    app                30          202
# 1  amazon    amz                50          175
# 2  google    ggl                70          160
# 3   tesla    tsl               100          240

# %%
ab = portfolio_df['Share price']

# %%
bc = portfolio_df['Number of shares']

# %%
stocks_dollar_value = ab*bc
stocks_dollar_value
# Out:
# 0     6060
# 1     8750
# 2    11200
# 3    24000
# dtype: int64

# %%
stocks_dollar_value.sum()
# Out:
# 50010

# %% [markdown]
# # 2. INPUTS (READ CSV AND HTML DATA)

# %%
# Pandas is used to read a csv file and store data in a DataFrame
ssup = pd.read_csv('N:\Personal Learning\Pandas\Pandas_Series\S_P500_Prices.csv')
ssup
# Out:
#             sp500
# 0     1295.500000
# 1     1289.089966
# 2     1293.670044
# 3     1308.040039
# 4     1314.500000
# ...           ...
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941
#
# [2159 rows x 1 columns]

# %%
# Read tabular data using read_html
house_prices_df = pd.read_html(' https://www.ssa.gov/oact/progdata/nra.html')
house_prices_df[0]
# Out:
#                                         Year of birth  \
# 0                                      1937 and prior
# 1                                                1938
# 2                                                1939
# 3                                                1940
# 4                                                1941
# 5                                                1942
# 6                                             1943-54
# 7                                                1955
# 8                                                1956
# 9                                                1957
# 10                                               1958
# 11                                               1959
# 12                                     1960 and later
# 13  Notes: 1. Persons born on January 1 of any yea...
#
#                                                   Age
# 0                                                  65
# 1                                     65 and 2 months
# 2                                     65 and 4 months
# 3                                     65 and 6 months
# 4                                     65 and 8 months
# 5                                    65 and 10 months
# 6                                                  66
# 7                                     66 and 2 months
# 8                                     66 and 4 months
# 9                                     66 and 6 months
# 10                                    66 and 8 months
# 11                                   66 and 10 months
# 12                                                 67
# 13  Notes: 1. Persons born on January 1 of any yea...

# %% [markdown]
# # 3. OUTPUTS (WRITE DATAFRAME INTO CSV)

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary
bank_df= pd.read_csv(r'N:\Personal Learning\Pandas\Pandas_Series\bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
bank_df.to_csv('sample_index.csv', index=True)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Use set index = False and rerun the cell. Comment on the output CSV.**
# - **Try to leverage the attribute compression and rerun the cell**

# %%
bank_df.to_csv('sample_flase_index.csv', index=False)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %% [markdown]
# # 4. SETTING/RESETTING INDEX

# %%
# Pandas is used to read a csv file and store data in a DataFrame
# Note that a numeric index is being set by default
bank_df= pd.read_csv('bank_client_information.csv')
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# You can assign a specific column to be the index as follows
bank_df.set_index('First Name', inplace=True)
bank_df
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# Samer                    26
# Heba                     11
# Laila                     3
# Joseph                    1
# Noah                     13

# %%
# You can go back and use numeric index using reset_index

bank_df.reset_index(inplace=True)
bank_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Alternatively, you can set the index name when you read the csv file as follows
bank_df = pd.read_csv('bank_client_information.csv', index_col='First Name')
bank_df
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# Samer                    26
# Heba                     11
# Laila                     3
# Joseph                    1
# Noah                     13

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Load the bank_client_information.csv and then set the "Last Name" column as the index**

# %%
bank_df = pd.read_csv('bank_client_information.csv', index_col='Last Name')
bank_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# Mo                      26
# Ismail                  11
# Ahmed                    3
# Patton                   1
# Moran                   13

# %% [markdown]
# # 5. SELECTING COLUMNS FROM A DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
banking_df = pd.read_csv(r'bank_client_information.csv')
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Return a column from the DataFrame
# Note that the output will be a Pandas Series (you can automatically tell by the lack of formating)
sample = banking_df['Email']
sample
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
type(sample)
# Out:
# pandas.core.series.Series

# %%
# Alternatively, you can use the following syntax to do the same
# Note that this method will not work if there are spaces in the column names
banking_df.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Since the column name has spaces, this will be the only way that will work!

banking_df['Net Worth']
# Out:
# 0      5000.00
# 1     10000.00
# 2      9072.02
# 3     11072.02
# 4      5000.00
# 5    100000.00
# 6     50000.00
# 7     20000.00
# 8      2629.13
# 9      8626.96
# Name: Net Worth, dtype: float64

# %%
# Let's select multiple columns from the DataFrame
# you need to define a list containing all column names that you would like to select
# Note that since we collected more than one column, the output is a DataFrame (Notice the rich formatting)
sample = banking_df[['First Name','Last Name', 'Net Worth']]
sample
# Out:
#   First Name Last Name  Net Worth
# 0      Bird      Steve    5000.00
# 1       Noah     Small   10000.00
# 2       Nina    Keller    9072.02
# 3    Chanel      Steve   11072.02
# 4       Kate      Noor    5000.00
# 5      Samer        Mo  100000.00
# 6       Heba    Ismail   50000.00
# 7      Laila     Ahmed   20000.00
# 8     Joseph    Patton    2629.13
# 9       Noah     Moran    8626.96

# %%
# Note that sample is now a DataFrame and not a Pandas Series (since it has multiple columns)
# You can use type to confirm or you can tell from the rich text formating
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
# Alternatively, you can define a list first and then use it to select columns
my_selection = ['First Name','Last Name', 'Net Worth']
sample = banking_df[my_selection]
sample
# Out:
#   First Name Last Name  Net Worth
# 0      Bird      Steve    5000.00
# 1       Noah     Small   10000.00
# 2       Nina    Keller    9072.02
# 3    Chanel      Steve   11072.02
# 4       Kate      Noor    5000.00
# 5      Samer        Mo  100000.00
# 6       Heba    Ismail   50000.00
# 7      Laila     Ahmed   20000.00
# 8     Joseph    Patton    2629.13
# 9       Noah     Moran    8626.96

# %%
# In order to access a given row in the dataframe
banking_df[0:2]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0     5000.0
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K    10000.0
#
#    Years with Bank
# 0                5
# 1                6

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Select the following columns from the dataFrame Net Worth, Years with Bank, and Postal Code**

# %%
sample = banking_df[['Net Worth','Years with Bank','Postal Code']]
sample
# Out:
#    Net Worth  Years with Bank Postal Code
# 0    5000.00                5     N94 3M0
# 1   10000.00                6     N8S 14K
# 2    9072.02                7     S1T 4E6
# 3   11072.02               10     N7T 3E6
# 4    5000.00               22     K8N 5H6
# 5  100000.00               26     J7H 3HY
# 6   50000.00               11     K8Y 3M8
# 7   20000.00                3     J8Y 3M0
# 8    2629.13                1     M6U 5U7
# 9    8626.96               13     K2D 4M9

# %% [markdown]
# # 6. ADDING/DELETING COLUMNS TO DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# Let's assume that we want to add a new column to the dataframe
banking_df['Age'] = [20,25,30,35,40,45,50,55,60,65]
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank  Age
# 0                5   20
# 1                6   25
# 2                7   30
# 3               10   35
# 4               22   40
# 5               26   45
# 6               11   50
# 7                3   55
# 8                1   60
# 9               13   65

# %%
# You can also insert a new column in a given position 
banking_df.insert(0, column='Credit Score', value=[500,525,550,575,600,625,650,675,700,725])

# %%
# Delete a column from a DataFrame
banking_df
# Out:
#    Credit Score First Name Last Name                    Email Postal Code  \
# 0           500      Bird      Steve           bird@gmail.com     N94 3M0
# 1           525       Noah     Small       nsmall@hotmail.com     N8S 14K
# 2           550       Nina    Keller          azikez@gahew.mr     S1T 4E6
# 3           575    Chanel      Steve         chanel@gmail.com     N7T 3E6
# 4           600       Kate      Noor         kate@hotmail.com     K8N 5H6
# 5           625      Samer        Mo          samer@gmail.com     J7H 3HY
# 6           650       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8
# 7           675      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0
# 8           700     Joseph    Patton           daafeja@boh.jm     M6U 5U7
# 9           725       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9
#
#    Net Worth  Years with Bank  Age
# 0    5000.00                5   20
# 1   10000.00                6   25
# 2    9072.02                7   30
# 3   11072.02               10   35
# 4    5000.00               22   40
# 5  100000.00               26   45
# 6   50000.00               11   50
# 7   20000.00                3   55
# 8    2629.13                1   60
# 9    8626.96               13   65

# %%
# Remove a column from a DataFrame and store it somehwere else using pop
del banking_df['Email']
banking_df
# Out:
#    Credit Score First Name Last Name Postal Code  Net Worth  Years with Bank  \
# 0           500      Bird      Steve     N94 3M0    5000.00                5
# 1           525       Noah     Small     N8S 14K   10000.00                6
# 2           550       Nina    Keller     S1T 4E6    9072.02                7
# 3           575    Chanel      Steve     N7T 3E6   11072.02               10
# 4           600       Kate      Noor     K8N 5H6    5000.00               22
# 5           625      Samer        Mo     J7H 3HY  100000.00               26
# 6           650       Heba    Ismail     K8Y 3M8   50000.00               11
# 7           675      Laila     Ahmed     J8Y 3M0   20000.00                3
# 8           700     Joseph    Patton     M6U 5U7    2629.13                1
# 9           725       Noah     Moran     K2D 4M9    8626.96               13
#
#    Age
# 0   20
# 1   25
# 2   30
# 3   35
# 4   40
# 5   45
# 6   50
# 7   55
# 8   60
# 9   65

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **load the bank_client_information.csv file and perform the following: (assume any reasonable values)**
#     - **Add a column indicating whether the client has a mortgage or not**
#     - **Add a column indicating the value of mortage in dollars**

# %%
banking_df = pd.read_csv(r'bank_client_information.csv')
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
banking_df['Mortgage']=['5000','10000','15000','20000','25000','30000','35000','40000','45000','50000']
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank Mortgage
# 0                5     5000
# 1                6    10000
# 2                7    15000
# 3               10    20000
# 4               22    25000
# 5               26    30000
# 6               11    35000
# 7                3    40000
# 8                1    45000
# 9               13    50000

# %% [markdown]
# # 7. LABEL-BASED ELEMENTS SELECTION FROM A DATAFRAME ".LOC()"

# %%
# Load the csv file and set the last name as the index
banking_df = pd.read_csv(r'bank_client_information.csv',index_col='Last Name')
banking_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#            Years with Bank
# Last Name
# Steve                    5
# Small                    6
# Keller                   7
# Steve                   10
# Noor                    22
# Mo                      26
# Ismail                  11
# Ahmed                    3
# Patton                   1
# Moran                   13

# %%
# Sort the dataframe in an alphabetical order
banking_df.sort_index( inplace=True)
banking_df
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
# Steve        Chanel          chanel@gmail.com     N7T 3E6   11072.02
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# Noor                    22
# Patton                   1
# Small                    6
# Steve                    5
# Steve                   10

# %%
# loc is used to filter rows and columns
# loc is label-based meaning you need to give a name of the rows (or columns) that you are interested in selecting
# Note that iloc is "integer index-based" meaning you can filter rows/columns by their integer index.
# Note that we obtained a Series because last name "Small" existed only once in the dataframe

banking_df.loc['Small']
# Out:
# First Name                       Noah
# Email              nsmall@hotmail.com
# Postal Code                   N8S 14K
# Net Worth                     10000.0
# Years with Bank                     6
# Name: Small, dtype: object

# %%
# Note that you got a DataFrame back since Last Name 'Steve' existed more than one in the DataFrame
banking_df.loc['Steve']
# Out:
#           First Name             Email Postal Code  Net Worth  Years with Bank
# Last Name
# Steve          Bird     bird@gmail.com     N94 3M0    5000.00                5
# Steve        Chanel   chanel@gmail.com     N7T 3E6   11072.02               10

# %%
# Note that you can select multiple rows using "colon :"
# Note that this is inclusive! meaning that "Ahmed" and "Patton" were selected in the output DataFrame
# Headsup: this will be different if we use integer based index such as iloc()

banking_df['Ahmed':'Patton']
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Mo             Samer          samer@gmail.com     J7H 3HY  100000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Noor            Kate         kate@hotmail.com     K8N 5H6    5000.00
# Patton        Joseph           daafeja@boh.jm     M6U 5U7    2629.13
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7
# Mo                      26
# Moran                   13
# Noor                    22
# Patton                   1

# %%
# Select all elements up to and including 'Keller' index
# Ensure the index is set to the correct column
banking_df.loc[:'Keller']
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Ahmed          Laila      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
#
#            Years with Bank
# Last Name
# Ahmed                    3
# Ismail                  11
# Keller                   7

# %%
# if you want to select multiple rows, you can pass them as a list as follows
banking_df.loc[['Keller','Steve','Mo']]
# Out:
#           First Name             Email Postal Code  Net Worth  Years with Bank
# Last Name
# Keller          Nina   azikez@gahew.mr     S1T 4E6    9072.02                7
# Steve          Bird     bird@gmail.com     N94 3M0    5000.00                5
# Steve        Chanel   chanel@gmail.com     N7T 3E6   11072.02               10
# Mo             Samer   samer@gmail.com     J7H 3HY  100000.00               26

# %%
# You can also randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns
banking_df.sample(n=5, axis=0)
# Out:
#           First Name                    Email Postal Code  Net Worth  \
# Last Name
# Keller          Nina          azikez@gahew.mr     S1T 4E6    9072.02
# Ismail          Heba  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Moran           Noah        guutodi@bigwoc.kw     K2D 4M9    8626.96
# Small           Noah       nsmall@hotmail.com     N8S 14K   10000.00
# Steve          Bird            bird@gmail.com     N94 3M0    5000.00
#
#            Years with Bank
# Last Name
# Keller                   7
# Ismail                  11
# Moran                   13
# Small                    6
# Steve                    5

# %%
# return a percentage (Ex: 30%) of the rows 
banking_df.sample(frac=0.3, axis=0)
# Out:
#           First Name               Email Postal Code  Net Worth  \
# Last Name
# Small           Noah  nsmall@hotmail.com     N8S 14K   10000.00
# Moran           Noah   guutodi@bigwoc.kw     K2D 4M9    8626.96
# Keller          Nina     azikez@gahew.mr     S1T 4E6    9072.02
#
#            Years with Bank
# Last Name
# Small                    6
# Moran                   13
# Keller                   7

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Load the csv data and use the "first name" column as the index**
# - **Randomly select 2 rows from the DataFrame. Rerun the code and ensure that random rows are being selected**

# %%
banks = pd.read_csv(r'bank_client_information.csv')
banks
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
banks.set_index('First Name')
# Out:
#            Last Name                    Email Postal Code  Net Worth  \
# First Name
# Bird           Steve           bird@gmail.com     N94 3M0    5000.00
# Noah           Small       nsmall@hotmail.com     N8S 14K   10000.00
# Nina          Keller          azikez@gahew.mr     S1T 4E6    9072.02
# Chanel         Steve         chanel@gmail.com     N7T 3E6   11072.02
# Kate            Noor         kate@hotmail.com     K8N 5H6    5000.00
# Samer             Mo          samer@gmail.com     J7H 3HY  100000.00
# Heba          Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# Laila          Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# Joseph        Patton           daafeja@boh.jm     M6U 5U7    2629.13
# Noah           Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#             Years with Bank
# First Name
# Bird                      5
# Noah                      6
# Nina                      7
# Chanel                   10
# Kate                     22
# Samer                    26
# Heba                     11
# Laila                     3
# Joseph                    1
# Noah                     13

# %%
banks.sample(n=2, axis=0)
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor   kate@hotmail.com     K8N 5H6    5000.00
#
#    Years with Bank
# 9               13
# 4               22

# %% [markdown]
# # 8. INTEGER INDEX-BASED ELEMENTS SELECTION FROM A DATAFRAME "iLOC()"

# %%
# Load the CSV file with default index
banking_df = pd.read_csv(r"N:\Personal Learning\Pandas\Pandas_Series\bank_client_information.csv")
banking_df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
# You can access rows with their numeric index using iloc
banking_df.iloc[4]
# Out:
# First Name                     Kate
# Last Name                      Noor
# Email              kate@hotmail.com
# Postal Code                 K8N 5H6
# Net Worth                    5000.0
# Years with Bank                  22
# Name: 4, dtype: object

# %%
# You can access multiple rows with their numeric index using iloc and colon :
# Note that using iloc is exclusive, meaning that we did not include the last element (quite confusing I know!)
# We went from index = 2 up until and not including index 5 so index 2,3, and 4 are the one selected
banking_df.iloc[2:5]
# Out:
#   First Name Last Name             Email Postal Code  Net Worth  \
# 2       Nina    Keller   azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve  chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor  kate@hotmail.com     K8N 5H6    5000.00
#
#    Years with Bank
# 2                7
# 3               10
# 4               22

# %%
# all up until and not including index 4
banking_df.iloc[:4]
# Out:
#   First Name Last Name               Email Postal Code  Net Worth  \
# 0      Bird      Steve      bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small  nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller     azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve    chanel@gmail.com     N7T 3E6   11072.02
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10

# %%
# Multiple elements are selected using a list of indexes 
banking_df.iloc[[2,4,6]]
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
#
#    Years with Bank
# 2                7
# 4               22
# 6               11

# %%
# Slicing a piece of the dataframe by selecting which row and column you would like to select
banking_df.iloc[2, 2:4]
# Out:
# Email          azikez@gahew.mr
# Postal Code            S1T 4E6
# Name: 2, dtype: object

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Write a code that selects the last two rows in the DataFrame using two different methods**

# %%
banking_df[-2:]
# Out:
#   First Name Last Name              Email Postal Code  Net Worth  \
# 8     Joseph    Patton     daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran  guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 8                1
# 9               13

# %% [markdown]
# # 9. BROADCASTING OPERATIONS & SETTING NEW DATAFRAME VALUES

# %%
# Pandas is used to read a csv file and store data in a DataFrame

# %%
# Let's assume that we want to update the networth of all our customers by $1000

# %%
# Alternatively, you can add or subtract as follows

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD

# %%
# Decided to update the email address of a given customer

# %%
# Let's assume we want to update the networth of two clients

# %% [markdown]
# **MINI CHALLENGE #9:**
# - **Let's assume that all clients in the bank has been investing their assets in a broad S&P500 ETF. The market has been performing really well and clients networth has increased by 12% annualy. Calculate the sum of all client's networth.**

# %%
#mini
# Out:
#   Cell In[64], line 1
#     **MINI CHALLENGE #9:**
#     ^
# SyntaxError: invalid syntax
